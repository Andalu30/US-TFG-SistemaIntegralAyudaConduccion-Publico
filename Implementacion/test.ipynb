# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
delante = cv2.imread('resources/templatesCalzada/eval2.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(delante)

# %%
template = cv2.imread('resources/templatesFlechas/DelanteIzq.png')
template = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)

plt.imshow(template)

# %%
res = cv2.matchTemplate(delante,template,cv2.TM_CCOEFF_NORMED)
threshold = 0.8
loc = np.where( res >= threshold)

# %%
loc
# Out:
# (array([13, 14, 14]), array([39, 39, 40]))

# %%
test = delante.copy()
for pt in zip(*loc[::-1]):
    cv2.rectangle(test, pt, (pt[0] + w, pt[1] + h), (255,255,255), 2)
plt.imshow(test)
