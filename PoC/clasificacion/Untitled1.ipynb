# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('testSemaforo.h5')

# %%
test_img = cv2.imread('/mnt/Datos/Descargas/LISA traffic light dataset/test/validacion/go/1000.jpg')
#test_img = cv2.cvtColor(test_img, cv2.COLOR_RGB2BGR)

test_img = cv2.resize(test_img, (150,150))
plt.imshow(test_img)

test_img = np.expand_dims(test_img, axis=0)


model.predict_classes(test_img)
# Out:
# array([[0]], dtype=int32)
